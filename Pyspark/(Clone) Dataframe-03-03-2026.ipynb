# %%
# read a table
amount_df=spark.table("samples.nyctaxi.trips")
display(amount_df)

# %%
from pyspark.sql import functions as F
#adding a new fields
amount_df=amount_df.withColumn("fair_amount_inr",(F.col("fare_amount")*92))
display(amount)

# %%
#adding a dummy column by using lit
amount_df=(amount_df.withColumn("pickup_zip",F.col("pickup_zip").cast("string"))
        .withColumn("dummy1",F.lit("dummy"))
        .withColumn("dummy2",F.lit("dummy1")))
display(amount)

# %%
#rename a column
amount_df=amount_df.withColumnRenamed("trip_distance","trip distance")
display(amount_df)

# %%
# %sql
select trip_distance from samples.nyctaxi.trips;

# %%
amount_df=spark.table("samples.nyctaxi.trips")
display(amount_df)

# %%
#we can also use sql in pyspark as below
amount_df=spark.sql("Select count (*) from samples.nyctaxi.trips")
display(amount_df)

# %%
from pyspark.sql import functions as F
amount_df=spark.table("samples.nyctaxi.trips")
display(amount_df)

# %%
amount_df.columns

# %%
#selecting mutiple columns
amount_df=amount_df.select("trip_distance","pickup_zip")
display(amount_df)

# %%
#this is other way for selecting mutiple columns
amount_df=amount_df.select(F.col("trip_distance"),F.column("pickup_zip"))
amount_df.show()

# %%
#we use this for limiting the rows
amount_df=amount_df.limit(5)
display(amount_df)

# %%
amount_df=spark.table("samples.nyctaxi.trips")
display(amount_df)

# %%
#returns first 5 records like head
amount_df=amount_df[:5]
print(amount_df)

# %%
#returns last 5 records like tail
amount_df=amount_df[-5:]
print(amount_df)

# %%
from pyspark.sql import functions as F
amount_df=spark.table("samples.nyctaxi.trips")
display(amount_df)

# %%
amount_df.printSchema()

# %%
amount_df.schema

# %%
amount_df.collect()

# %%
amount_df.count()

# %%
amount_df.head(5)

# %%
amount_df.tail(5)
